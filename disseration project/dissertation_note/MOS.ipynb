# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
project_path = "/content/drive/MyDrive/dissertation project/dissertation_note"
os.chdir(project_path)
print("Change to the location:", os.getcwd())
# Out:
# Change to the location: /content/drive/MyDrive/dissertation project/dissertation_note

# %%
! git clone https://github.com/gabrielmittag/NISQA
# Out:
# fatal: destination path 'NISQA' already exists and is not an empty directory.

# %%
# %cd ./NISQA
# Out:
# /content/drive/MyDrive/dissertation project/dissertation_note/NISQA

# %%
# !mkdir -p results

# %%
# !python run_predict.py \
  --mode predict_dir \
  --pretrained_model weights/nisqa.tar \
  --data_dir "/content/drive/MyDrive/dissertation project/dissertation_note/batch_outputs2" \
  --num_workers 1 \
  --bs 10 \
  --output_dir ./results1
# Out:
# Device: cuda
# Model architecture: NISQA_DIM
# Loaded pretrained model from weights/nisqa.tar
# # files: 600
# ---> Predicting ...
# /usr/local/lib/python3.11/dist-packages/librosa/feature/spectral.py:2148: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
#                                    deg  mos_pred  noi_pred  dis_pred  col_pred  loud_pred   model
# 000_Little_Tim_fills_the_silver_li.wav  4.479989  4.622755  4.433949  4.002416   4.308187 NISQAv2
# 001_A_star_parks_near_the_large_pa.wav  4.168156  4.318362  4.061402  3.898969   4.233099 NISQAv2
# 002_Anna_offers_a_proper_answer_be.wav  4.264938  4.631527  4.838537  4.496586   4.636313 NISQAv2
# 003_He_feed_cheese_pieces_each_wee.wav  4.395907  4.322851  4.269875  4.001191   4.327588 NISQAv2
# ...
